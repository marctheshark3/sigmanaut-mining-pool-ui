# %%
from utils.api_2_db import DataSyncer
import pandas as pd
from utils.update_blocks_and_workers import update_blocks_and_live_workers
from utils.update_payment_and_performance import update_payment_and_performance
from utils.update_pool_stats import update_pool_stats
from utils.init_db import init_db

# %%
db_sync = DataSyncer(config_path="../conf")
miner = '9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPVApYkk'

# %%
init_db()
# Out:
# intializing DB
# UPDATED STATS TABLE SUCCESFULLY
# UPDATED BLOCK TABLE SUCCESFULLY
# /home/whaleshark/Documents/sigmanaut-mining-pool-ui/utils/db_util.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
# Index(['fee', 'paid', 'blocks', 'last_block_found', 'enabled',
#        'minimumpayment', 'payoutscheme', 'connectedminers', 'poolhashrate',
#        'sharespersecond', 'networktype', 'networkhashrate',
#        'networkdifficulty', 'lastnetworkblocktime', 'blockheight',
#        'connectedpeers', 'rewardtype', 'pooleffort', 'poolttf', 'price',
#        'insert_time_stamp'],
#       dtype='object')
# no live data for miner 9eZVqXVnrVWQKK19b7E7kp4ZyNqanp2z1mpKUJRaouNsmeFsakQ
# no live data for miner 9hyzuf6zUyWR2z3vTBCkwXNceCE3WuVVhVLMzEDUsdu5rqHq525
# no live data for miner 9goKZ76KWv6JNJUDLgPh6c7873t1qr5fYYNpyr7p8wD65nAznfi
# no live data for miner 9fGzn8VCszvFMXo2KDrQiVowwSdchVT13ygX26RKUfkjcruRq7J
# no live data for miner 9iHhp79F5CXRq3DYS4urz8q4aDyLAx1L5d6cyucrh9gPqDepj17
# no live data for miner 9gyKCPYkaBJp7z8NxxCygjwB6u9GLudiakUEUPpZ1bjhbJUip8z
# no live data for miner 9fvDaBsLKmzP67Cp2i2bmhM1359HhJCrej8y5EGoUcmXDrBqxbW
# no live data for miner 9h1B5mgnHMpLtJfSxuBkgiD2GUYUKbuoYw5pokhhEdJxtJMLrM6
# UPDATED LIVE WORK, PERFORMANCE, AND PAYMENT TABLES SUCCESFULLY
# complete

# %%
update_pool_stats()
# Out:
# UPDATED STATS TABLE SUCCESFULLY

# %%
update_blocks_and_live_workers()
# Out:
# UPDATED BLOCK TABLE SUCCESFULLY
# /home/whaleshark/Documents/sigmanaut-mining-pool-ui/utils/db_util.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# Index(['fee', 'paid', 'blocks', 'last_block_found', 'enabled',
#        'minimumpayment', 'payoutscheme', 'connectedminers', 'poolhashrate',
#        'sharespersecond', 'networktype', 'networkhashrate',
#        'networkdifficulty', 'lastnetworkblocktime', 'blockheight',
#        'connectedpeers', 'rewardtype', 'pooleffort', 'poolttf', 'price',
#        'insert_time_stamp'],
#       dtype='object')
# no live data for miner 9eZVqXVnrVWQKK19b7E7kp4ZyNqanp2z1mpKUJRaouNsmeFsakQ
# no live data for miner 9hyzuf6zUyWR2z3vTBCkwXNceCE3WuVVhVLMzEDUsdu5rqHq525
# no live data for miner 9goKZ76KWv6JNJUDLgPh6c7873t1qr5fYYNpyr7p8wD65nAznfi
# no live data for miner 9fGzn8VCszvFMXo2KDrQiVowwSdchVT13ygX26RKUfkjcruRq7J
# no live data for miner 9iHhp79F5CXRq3DYS4urz8q4aDyLAx1L5d6cyucrh9gPqDepj17
# no live data for miner 9gyKCPYkaBJp7z8NxxCygjwB6u9GLudiakUEUPpZ1bjhbJUip8z
# no live data for miner 9fvDaBsLKmzP67Cp2i2bmhM1359HhJCrej8y5EGoUcmXDrBqxbW
# UPDATED LIVE WORK, PERFORMANCE, AND PAYMENT TABLES SUCCESFULLY

# %%
update_payment_and_performance()
# Out:
# /home/whaleshark/Documents/sigmanaut-mining-pool-ui/utils/db_util.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
# Index(['fee', 'paid', 'blocks', 'last_block_found', 'enabled',
#        'minimumpayment', 'payoutscheme', 'connectedminers', 'poolhashrate',
#        'sharespersecond', 'networktype', 'networkhashrate',
#        'networkdifficulty', 'lastnetworkblocktime', 'blockheight',
#        'connectedpeers', 'rewardtype', 'pooleffort', 'poolttf', 'price',
#        'insert_time_stamp'],
#       dtype='object')
# UPDATED LIVE WORK, PERFORMANCE, AND PAYMENT TABLES SUCCESFULLY

# %%
update_pool_stats()
# Out:
# UPDATED STATS TABLE SUCCESFULLY

# %%
df = db_sync.db.fetch_data('payment')
df = df[df.miner == miner]
dates = df.lastpayment.unique()

ls = []
for date in dates:
    temp = df[df.lastpayment == date]
    temp = temp[temp.created_at == max(temp.created_at)]
    ls.append(temp)

new_df = pd.concat(ls)
new_df
# Out:
# /home/whaleshark/Documents/sigmanaut-mining-pool-ui/utils/db_util.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
#        pendingshares  pendingbalance  totalpaid  todaypaid schema  price  \
# 1255           98.33             0.0     338.45   1.464749  PPLNS   1.18
# 13926         190.96             0.0     343.88   0.000000  PPLNS   1.30
# 20811         118.14             0.0     345.20   1.321936  PPLNS   1.29
# 29657         112.89             0.0     347.87   3.990570  PPLNS   1.33
#
#       lastpayment                                    lastpaymentlink  \
# 1255   2024-05-08  https://explorer.ergoplatform.com/en/transacti...
# 13926  2024-05-09  https://explorer.ergoplatform.com/en/transacti...
# 20811   2024-05-1  https://explorer.ergoplatform.com/en/transacti...
# 29657  2024-05-10  https://explorer.ergoplatform.com/en/transacti...
#
#                       created_at  \
# 1255  2024-05-08 11:56:01.671197
# 13926 2024-05-09 22:42:01.648600
# 20811 2024-05-10 03:02:02.208291
# 29657 2024-05-10 08:28:30.001426
#
#                                                    miner
# 1255   9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...
# 13926  9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...
# 20811  9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...
# 29657  9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...

# %%
db_sync.db.get_db_size()
# Out:
# '23 MB'

# %%
df = db_sync.db.fetch_data('live_worker')
df = df[df.created == max(df.created)]
df = df[df.worker == 'totals']
df
# Out:
# /home/whaleshark/Documents/sigmanaut-mining-pool-ui/utils/db_util.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
#        worker  hashrate  shares_per_second             created  \
# 35215  totals   33013.0               2.13 2024-05-10 14:28:34
# 35219  totals    4645.0               0.21 2024-05-10 14:28:34
# 35224  totals    4072.0               0.30 2024-05-10 14:28:34
# 35226  totals    1340.0               0.05 2024-05-10 14:28:34
# 35230  totals    3715.0               0.21 2024-05-10 14:28:34
# 35316  9gBRV9wuTabhMtqxTPBPZZBqEC3M6U64wjakuud3iyVZkx...    0.00   60.03
# 35318  9f1gJS9FhVsBZPZZ4goGsKKqj5EzniSVYpH9WcEi1jxa2Y...    0.00   73.39
# 35320  9eiBDqvLs2Z5PobwMmHtZsczn7a4yy73mYsKghkqgCZ5Nf...    0.00   65.18
# 35323  9gqJXY1t7mUn7rurrcbdY1td226N1TwzDHRZ1xXeUiUERZ...    0.00   69.04
# 35325  9gLRSzqiMGdMU39jG6hMAnwHT748HiTrY6wz1jjFGkJYaM...    0.00   66.93
# 35327  9hYeUWUG2dAM6sZb9vr5qgF1gACEGQPLN9cbXjxERmJS89...    0.00   60.65
# 35329  9enXTiL3i9CKWKCcE3fby2hSaeoWEWV28evc1j1SK9yKRD...    0.00   75.95
# 35331  9hVL55CcVcvWsNEis6Q2JdeizJfvQ34vKgv8qSBYRM7eBh...    0.00  102.15
# 35333  9g69FNxqfPEzTEjQHeAUnC86FG95YDtHEZqc7enVvcKKip...    0.00  119.64
# 35335  9iGCyowxwgf6cQef1RfEw6UCYoHJi6q1hZvKvcWyFY1kuL...    0.00   71.01
# 35337  9gWtU5oRt4yuNU4WELRAHm49CCpwtRoVRkjs1DQkoKZmEu...    0.00  135.41
# 35339  9hJsB9ZaFJJBxQWEaMKGL4Jr1xm2TErCRVkBzdvtD9S8YL...    0.00   94.93
#
#           last_block_found
# 35215  2024-05-10 08:26:21
# 35219  2024-05-10 02:15:36
# 35224  2024-05-03 20:46:06
# 35226  2024-05-10 13:35:01
# 35230  2024-04-28 23:18:22
# 35236  2024-05-08 16:41:29
# 35240                  N/A
# 35245  2024-05-03 12:13:18
# 35248  2024-05-10 06:30:40
# 35250                  N/A
# 35252  2024-04-28 16:09:49
# 35254                  N/A
# 35258  2024-05-06 01:55:23
# 35261                  N/A
# 35264  2024-04-28 03:06:52
# 35267  2024-05-07 17:45:32
# 35269                  N/A
# 35271                  N/A
# 35273  2024-04-17 01:03:11
# 35277                  N/A
# 35279  2024-05-02 01:51:57
# 35282  2024-04-29 08:20:04
# 35284  2024-04-28 17:16:48
# 35286                  N/A
# 35288  2024-04-13 01:40:15
# 35291                  N/A
# 35293                  N/A
# 35295                  N/A
# 35297  2024-04-26 18:24:58
# 35299                  N/A
# 35302  2024-04-22 22:07:16
# 35305                  N/A
# 35308  2024-04-23 12:18:50
# 35311  2024-04-22 18:11:34
# 35314  2024-04-07 19:55:43
# 35316                  N/A
# 35318                  N/A
# 35320                  N/A
# 35323                  N/A
# 35325                  N/A
# 35327                  N/A
# 35329                  N/A
# 35331                  N/A
# 35333                  N/A
# 35335                  N/A
# 35337                  N/A
# 35339                  N/A

# %%
df = db_sync.db.fetch_data('payment')
df = df[df.miner == miner]
dates = df.lastpayment.unique() # get all of the payment dates
ls = []
for date in dates:
    temp = df[df.lastpayment == date]
    temp = temp[temp.created_at == max(temp.created_at)] # filter by the latest payment stamp
    ls.append(temp)

df = pd.concat(ls)
df
# Out:
#        pendingshares  pendingbalance  totalpaid  todaypaid schema  price  \
# 1255           98.33             0.0     338.45   1.464749  PPLNS   1.18
# 13927         190.96             0.0     343.88   0.000000  PPLNS   1.30
# 20812         118.14             0.0     345.20   1.321936  PPLNS   1.29
# 31063         123.67             0.0     347.87   3.990570  PPLNS   1.31
#
#       lastpayment                                    lastpaymentlink  \
# 1255   2024-05-08  https://explorer.ergoplatform.com/en/transacti...
# 13927  2024-05-09  https://explorer.ergoplatform.com/en/transacti...
# 20812   2024-05-1  https://explorer.ergoplatform.com/en/transacti...
# 31063  2024-05-10  https://explorer.ergoplatform.com/en/transacti...
#
#                       created_at  \
# 1255  2024-05-08 11:56:01.671197
# 13927 2024-05-09 22:42:01.648600
# 20812 2024-05-10 03:02:02.208291
# 31063 2024-05-10 09:20:02.261625
#
#                                                    miner
# 1255   9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...
# 13927  9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...
# 20812  9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...
# 31063  9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...

# %%
dates = [date for date in df['lastpayment'] if len(date) > 9]
df[df['lastpayment'].isin(dates)]
# Out:
#        pendingshares  pendingbalance  totalpaid  todaypaid schema  price  \
# 1255           98.33             0.0     338.45   1.464749  PPLNS   1.18
# 13927         190.96             0.0     343.88   0.000000  PPLNS   1.30
# 31063         123.67             0.0     347.87   3.990570  PPLNS   1.31
#
#       lastpayment                                    lastpaymentlink  \
# 1255   2024-05-08  https://explorer.ergoplatform.com/en/transacti...
# 13927  2024-05-09  https://explorer.ergoplatform.com/en/transacti...
# 31063  2024-05-10  https://explorer.ergoplatform.com/en/transacti...
#
#                       created_at  \
# 1255  2024-05-08 11:56:01.671197
# 13927 2024-05-09 22:42:01.648600
# 31063 2024-05-10 09:20:02.261625
#
#                                                    miner
# 1255   9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...
# 13927  9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...
# 31063  9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPV...

# %%
df

# %%
url = '{}/{}/{}'.format(db_sync.base_api, 'miners', miner)
mining_data = db_sync.get_api_data(url)        
payment_data = {k: v for k, v in mining_data.items() if k not in ['performance', 'performanceSamples']}
payment_data['lastPayment'] = mining_data['lastPayment'] #[:-16]
payment_data
# Out:
# {'pendingShares': 116.40513072356909,
#  'pendingBalance': 0.0,
#  'totalPaid': 347.872660492083,
#  'todayPaid': 3.990569760996,
#  'lastPayment': '2024-05-10T11:03:20.275464Z',
#  'lastPaymentLink': 'https://explorer.ergoplatform.com/en/transactions/2c4f1128ceba4742f0f7cc2353d5c218a743f7fcbf1cd347c78f668588788ef0'}

# %%
payment_data
# Out:
# {'pendingShares': 116.40513072356909,
#  'pendingBalance': 0.0,
#  'totalPaid': 347.872660492083,
#  'todayPaid': 3.990569760996,
#  'lastPayment': '2024-05-10T11:03:20.275464Z',
#  'lastPaymentLink': 'https://explorer.ergoplatform.com/en/transactions/2c4f1128ceba4742f0f7cc2353d5c218a743f7fcbf1cd347c78f668588788ef0'}

# %%
df = db_sync.db.fetch_data('block')
bf = df[df.time_found == max(df.time_found)]
bf.confirmationprogress.item()
# Out:
# 57
