# %%
from utils.api_2_db import DataSyncer
import pandas as pd
from utils.update_blocks_and_workers import update_blocks_and_live_workers
from utils.update_payment_and_performance import update_payment_and_performance
from utils.update_pool_stats import update_pool_stats
from utils.init_db import init_db

# %%
init_db()
# Out:
# intializing DB
# Connecting to DB instance
# connected
# tables created
# UPDATED STATS TABLE SUCCESFULLY
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 init_db()
#
# File ~/Documents/ergo/sigma-dashboard/utils/init_db.py:25, in init_db()
#      23 db_sync.update_pool_stats(timenow)
#      24 # db_sync.db.fetch_data('stats')
# ---> 25 db_sync.update_block_data(timenow)
#      26 # db_sync.db.fetch_data('block')
#      27 # print('miner data')
#      28 db_sync.update_miner_data(timenow)
#
# File ~/Documents/ergo/sigma-dashboard/utils/api_2_db.py:215, in DataSyncer.update_block_data(self, timenow)
#     213 data['time_found'] = data.pop('created')
#     214 data['confirmationProgress'] = data['confirmationProgress'] * 100
# --> 215 data['networkDifficulty'] = round(data['networkDifficulty'], 2)
#     216 try:
# ...

# %%
db_sync = DataSyncer(config_path="../conf")
miner = '9ehJZvPDgvCNNd2zTQHxnSpcCAtb1kHbEN1VAgeoRD5DPVApYkk'
# db_sync.db.create_database('sigma-mining-db')
# Out:
# Connecting to DB instance
# connected

# %%
def get_size_and_tables():
    print(db_sync.db.get_db_size())
    df = db_sync.db.fetch_data('payment')
    print(len(df), 'PAYMENT')
    
    df = db_sync.db.fetch_data('live_worker')
    print(len(df), 'LIVE')
    
    df = db_sync.db.fetch_data('stats')
    print(len(df), 'STATS',)
    
    df = db_sync.db.fetch_data('block')
    print(len(df), 'BLOCKS')

# %%
get_size_and_tables()
# Out:
# 10 MB
# 163 PAYMENT
# 524 LIVE
# 26 STATS
# 164 BLOCKS
# /home/whaleshark/Documents/ergo/sigma-dashboard/utils/db_util.py:265: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)

# %%
db_sync.db.fetch_data('stats')
# Out:
# /home/whaleshark/Documents/ergo/sigma-dashboard/utils/db_util.py:265: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
#     fee         paid  blocks    last_block_found  enabled  minimumpayment  \
# 0   0.9  4321.094287     164 2024-05-28 19:31:53     True             0.5
# 1   0.9  4321.094287     164 2024-05-28 19:31:53     True             0.5
# 2   0.9  4321.094287     164 2024-05-28 19:31:53     True             0.5
# 3   0.9  4321.094287     164 2024-05-28 19:31:53     True             0.5
# 4   0.9  4321.094287     164 2024-05-28 19:31:53     True             0.5
# 5   0.9  4321.094287     164 2024-05-28 19:31:53     True             0.5
# 6   0.9  4321.094287     164 2024-05-28 19:31:53     True             0.5
# ...

# %%
db_sync.db.create_table('block', db_sync.block_headers)
# Out:
# True

# %%
db_sync.db.create_table('payment', db_sync.payment_headers)
db_sync.db.fetch_data('payment')
# Out:
# /home/whaleshark/Documents/ergo/sigma-dashboard/utils/db_util.py:265: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
#      pendingshares  pendingbalance  totalpaid  todaypaid schema  price  \
# 0          2103.52            0.00     812.40        0.0  PPLNS   1.21
# 1           437.62            0.00      41.07        0.0  PPLNS   1.21
# 2           345.63            0.00     277.99        0.0  PPLNS   1.21
# 3            40.21            0.00      43.65        0.0  PPLNS   1.21
# 4           305.79            6.44     443.33        0.0  PPLNS   1.21
# ..             ...             ...        ...        ...    ...    ...
# 158           7.18            0.33       1.73        0.0  PPLNS   1.21
# 159           5.27            0.45       3.60        0.0  PPLNS   1.21
# ...

# %%
db_sync.db.create_table('live_worker', db_sync.live_worker_headers)
db_sync.db.fetch_data('live_worker')
# Out:
# /home/whaleshark/Documents/ergo/sigma-dashboard/utils/db_util.py:265: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
#         worker  hashrate  shares_per_second             created  \
# 0    d_tim_4_v    1368.0               0.07 2024-05-28 20:56:48
# 1    e_tim_5_v     918.0               0.07 2024-05-28 20:56:48
# 2    f_tim_6_v     954.0               0.07 2024-05-28 20:56:48
# 3      h_tim_8    1582.0               0.08 2024-05-28 20:56:48
# 4     j_tim_10     630.0               0.05 2024-05-28 20:56:48
# ..         ...       ...                ...                 ...
# 519     totals      63.0               0.01 2024-05-28 21:00:48
# 520   aliens69      54.0               0.01 2024-05-28 21:00:48
# 521     totals      54.0               0.01 2024-05-28 21:00:48
# ...

# %%
db_sync.db.create_table('performance',db_sync.performance_headers)
db_sync.db.fetch_data('performance')
# Out:
# /home/whaleshark/Documents/ergo/sigma-dashboard/utils/db_util.py:265: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
#        worker  hashrate  shares_per_second             created  \
# 0      totals    156.12               0.03 2024-05-28 12:00:00
# 1      totals    163.56               0.04 2024-05-28 13:00:00
# 2                152.86               0.03 2024-05-28 14:00:00
# 3      totals    152.86               0.03 2024-05-28 14:00:00
# 4                144.08               0.03 2024-05-28 15:00:00
# ...       ...       ...                ...                 ...
# 3958     Rig1    632.37               0.07 2024-05-28 13:00:00
# 3959   totals    686.06               0.08 2024-05-28 13:00:00
# 3960  RIG_luc     65.21               0.01 2024-05-28 14:00:00
# ...

# %%
flag = db_sync.__create_table__()
flag
# Out:
# True

# %%
get_size_and_tables()
# Out:
# 8689 kB

# %%
init_db()
# Out:
# intializing DB
# Connecting to DB instance
# connected
# tables created
# UPDATED STATS TABLE SUCCESFULLY
# UPDATED BLOCK TABLE SUCCESFULLY
# /home/whaleshark/Documents/ergo/sigma-dashboard/utils/db_util.py:269: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
# no live data for miner 9hwEKqgW4XjRi7uYjRcsZHiRiuNT3dMHsR3J75BNSrGDQyKuz8Q
# no live data for miner 9fmniVfPjpbcxoWA5n4SQvLPDzaNrtasHn7Jn7CLa57oinh1rtW
# UPDATED LIVE WORK, PERFORMANCE, AND PAYMENT TABLES SUCCESFULLY
# complete 9361 kB

# %%
get_size_and_tables()
# Out:
# 9361 kB

# %%
val = 'qx3090-9fYvQMsMN3NNaw33cAFnRdyHy1DpxtxfADvGqUV3ocLptw4HpcP'
len(val)
# Out:
# 58

# %%
update_pool_stats()
# Out:
# Connecting to DB instance
# connected
# UPDATED STATS TABLE SUCCESFULLY

# %%
update_blocks_and_live_workers()
# Out:
# Connecting to DB instance
# connected
# UPDATED BLOCK TABLE SUCCESFULLY
# /home/whaleshark/Documents/ergo/sigma-dashboard/utils/db_util.py:269: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
# no live data for miner 9hwEKqgW4XjRi7uYjRcsZHiRiuNT3dMHsR3J75BNSrGDQyKuz8Q
# no live data for miner 9fmniVfPjpbcxoWA5n4SQvLPDzaNrtasHn7Jn7CLa57oinh1rtW
# UPDATED LIVE WORK, PERFORMANCE, AND PAYMENT TABLES SUCCESFULLY

# %%
update_payment_and_performance()
# Out:
# Connecting to DB instance
# connected
# /home/whaleshark/Documents/ergo/sigma-dashboard/utils/db_util.py:269: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, self.conn)
# UPDATED LIVE WORK, PERFORMANCE, AND PAYMENT TABLES SUCCESFULLY

# %%
get_size_and_tables()
# Out:
# 9761 kB
